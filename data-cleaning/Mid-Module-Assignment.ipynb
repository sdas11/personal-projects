# %% [markdown]
# # Mid-Module Assigment - Data PreProcessing
#
# #### Loading the TSV
# For now, we don't load the TSV with specific column data types.
#
# From the cursory inspection, it looks like we would need to spend some effort in cleaning the last 2nd last column (column before Criteria). We would come back to it later after sanitising rest of the columns.

# %%
import pandas as pd
import numpy as np
import re
import json

df = pd.read_csv('./SIS_faculty_list.tsv', sep='\t', header=0)
# Let's fix the typo "divison" in the column name
df.rename(columns = {'Divison':'Division'}, inplace = True)
df.head(1)
# Out:
#           ID        Name Location Grade               Title  Join Date  LWD  \
# 0  LT9210743  Jim Hunter   London    FA  Faculty - Business  29-Aug-10  NaN
#
#         Type  Division   Reports To Highest Qualification Level  \
# 0  Full Time  Business  Abbas Houda                     Masters
#
#   Highest Qualification                  Major                     University  \
# 0        Master of Arts  International Affairs  American University of Beirut
#
#                      All Qualifications from Profile  \
# 0  Bachelor of Science (Communications), Master o...
#
#                          Courses Taught- Term 201510     MAJOR TEACHING FIELD  \
# 0  BUS2403 - Innovation & Entrepreneurship BUS200...  Business Administration
#
#   DOCUMENT OTHER PROFESSIONAL CERTIFICATION CRITIERA Five Years Work Experience Teaching Excellence Professional Certifications  \
# 0  10+ Years Small Business Ownership, 10+ Years ...
#
#                          Criteria
# 0  Industry & Teaching experience

# %%
# Utility functions

def check_is_empty(x):
    if x is None or pd.isna(x) or pd.isnull(x):
        return True
    else:
        return False

def check_is_not_empty(x):
    return not check_is_empty(x)

# %% [markdown]
# #### Inspecting for missing values
#
# From the output below, we can see that the series for LWD (Last Working Day) is 96% empty. This is a column we should `drop` - since we can't impute this column for missing values and the missing percentage is **too high**.

# %%
missing_percentages = (df.isnull().sum() / len(df)) * 100
for k, v in missing_percentages.items():
    if v > 10:
        print('Column: ' + k + ' has missing value %: ' + str(v))
# Out:
# Column: LWD has missing value %: 96.12676056338029
# Column: MAJOR TEACHING FIELD has missing value %: 20.774647887323944
# Column: DOCUMENT OTHER PROFESSIONAL CERTIFICATION CRITIERA Five Years Work Experience Teaching Excellence Professional Certifications has missing value %: 21.830985915492956

# %% [markdown]
# #### Dropping unneccessary columns - 'LWD'
# From the above inspection (for missing values), LWD is chosen to be dropped.

# %%
df.drop('LWD', axis=1, inplace=True)
print('LWD column is dropped')
# Out:
# LWD column is dropped

# %% [markdown]
# #### Dropping unneccessary columns - 'ID' and 'Name'
# I want to drop the `ID` and `Name` columns as well, since its a unique identifier and not useful for ML purposes. But before dropping the `ID` column, I want to make sure that there are `no duplicate rows` for `ID` and `Name` - which could `potentially help in imputing missing values`
#
# As we can see below, `no 2 IDs are repeated`.

# %%
# Filter all rows where ID = NaN or '0'
temp_check = df.dropna()
temp_check = temp_check.loc[temp_check['ID'] != '0']
ids = temp_check['ID']
temp_check[ids.isin(ids[ids.duplicated()])]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Location, Grade, Title, Join Date, Type, Division, Reports To, Highest Qualification Level, Highest Qualification, Major, University, All Qualifications from Profile, Courses Taught- Term 201510, MAJOR TEACHING FIELD, DOCUMENT OTHER PROFESSIONAL CERTIFICATION CRITIERA Five Years Work Experience Teaching Excellence Professional Certifications, Criteria]
# Index: []

# %% [markdown]
# As an additional check, we can also look at name duplications - which has only two instances - both of which, are for distinct persons (by looking at the data in rest of the columns)

# %%
# Lets see if any two rows have same name
names = df['Name']
df[names.isin(names[names.duplicated()])]
# Out:
#             ID           Name    Location Grade               Title  \
# 44   LT9276009  Amanda Hobson  Manchester    FA  Faculty - Business
# 45   LT9004065  Amanda Hobson         NaN    FA  Faculty - Business
# 131  LT9234672  Zikida Koudou     Cardiff    FA  Faculty - Business
# 144  LT9328996  Zikida Koudou     Belfast    FA  Faculty - Business
#
#      Join Date       Type  Division        Reports To  \
# 44   18-Aug-13  Full Time  Business        Ian Varley
# 45   16-Sep-02  Full Time  Business        Ian Varley
# 131  26-Aug-12  Full Time  Business    Harriet Mensah
# 144   9-Aug-15  Full Time  Business  Orlamei Princess
#
#     Highest Qualification Level   Highest Qualification  \
# 44                    Doctorate                    Ph.D
# 45                    Doctorate  Doctorate in Marketing
# 131                     Masters                 Masters
# 144                   Doctorate                    Ph.D
#
#                       Major                  University  \
# 44      Business Management  Univ of the Sunshine Coast
# 45                Marketing   University of Westminster
# 131  Hospitality Management       University of Houston
# 144       Economics Science    University of Montenegro
#
#                        All Qualifications from Profile  \
# 44   Ph.D (Business Management), Post Graduate Cert...
# 45   Master of Business Administrat (Business Admin...
# 131  Bachelor (Hotel Restaurant Tourism Admin), Mas...
# 144  Ph.D (Economics Science), Bachelor (Ecological...
#
#                            Courses Taught- Term 201510  \
# 44   BUS2203 - Business Stats for Managers BUS2303 ...
# 45   CSD1023 - The Crime of Smuggling BUS4563 - Str...
# 131  BUS1403 - Business Ethics and Corporate BUS120...
# 144  BUS3103 - Internat Busi Globalisation BSD2252 ...
#
#                                   MAJOR TEACHING FIELD  \
# 44                  Economics/ Business Administration
# 45                  Business Administration/ Marketing
# 131  Economics/Management/Marketing/Tourism/Hospita...
# 144                                                NaN
#
#     DOCUMENT OTHER PROFESSIONAL CERTIFICATION CRITIERA Five Years Work Experience Teaching Excellence Professional Certifications  \
# 44                 PGCE,  11 years teaching experience
# 45   ICDL IRB Instructional Skills Workshops (ISW) ...
# 131  Yrs of Teaching Experience  -  15 years   Prof...
# 144                                                NaN
#
#                            Criteria
# 44   Industry & Teaching experience
# 45   Industry & Teaching experience
# 131                   Certification
# 144  Industry & Teaching experience

# %%
df.drop('ID', axis=1, inplace=True)
print('ID column is dropped')

df.drop('Name', axis=1, inplace=True)
print('Name colum is dropped')
# Out:
# ID column is dropped
# Name colum is dropped

# %% [markdown]
# #### Inspecting For Typos - Location ... Major
# To do this, we simply take a frequency count, and manually inspect occurences which have low values (less than 5) - since typos are often not repeated.

# %%
column_names = ['Location', 'Grade', 'Title', 'Type', 'Division', 
                'Highest Qualification Level', 'Highest Qualification', 'Major']
for column_name in column_names:
    freqs = df[column_name].value_counts()
    for k, count in freqs.items():
        if count < 5:
            print('Low frequency count: ' + str(count) + ' for the value: ' + k + ' in column: ' + column_name)
    print('----')
# Out:
# Low frequency count: 1 for the value: Psychology in column: Major
# Low frequency count: 1 for the value: Professional Studies in column: Major
# Low frequency count: 1 for the value: E-Business in column: Major
# Low frequency count: 1 for the value: International Administration in column: Major
# Low frequency count: 1 for the value: Management Sciences in column: Major
# Low frequency count: 1 for the value: Educational Technology in column: Major
# Low frequency count: 1 for the value: Teaching in column: Major
# Low frequency count: 1 for the value: Commericial & Corporate Law in column: Major
# Low frequency count: 1 for the value: Instructional Technology in column: Major
# Low frequency count: 1 for the value: Educational Leadership in column: Major
# Low frequency count: 1 for the value: Financial Economics  in column: Major
# Low frequency count: 1 for the value: Strategic Business & IT in column: Major
# Low frequency count: 1 for the value: Public Administration in column: Major
# Low frequency count: 1 for the value: Agricultural  Economics in column: Major
# Low frequency count: 1 for the value: Management and Financial Mgt in column: Major
# Low frequency count: 1 for the value: Commerce & Management Studies in column: Major
# Low frequency count: 1 for the value: Economics& Management in column: Major
# Low frequency count: 1 for the value: TESOL in column: Major
# Low frequency count: 1 for the value: Business Computing Science in column: Major
# Low frequency count: 1 for the value: Business Info. Technology in column: Major
# Low frequency count: 1 for the value: Finance and Islamic Banking & Finance in column: Major
# Low frequency count: 1 for the value: Managerial Economics/ Business Strategy in column: Major
# Low frequency count: 1 for the value: Global Human Resource Mngt in column: Major
# Low frequency count: 1 for the value: HRD in column: Major
# Low frequency count: 1 for the value: HRM in column: Major
# Low frequency count: 1 for the value: Applied Business in column: Major
# Low frequency count: 1 for the value: Innovative Management in column: Major
# Low frequency count: 1 for the value: Operation Management in column: Major
# Low frequency count: 1 for the value: Economics and International Business  in column: Major
# Low frequency count: 1 for the value: Energy Management in column: Major
# ----

# %% [markdown]
# From the above, we can note the following things -
#
# *Columns which are OK*
# 1. Location
# 2. Grade
# 3. Type
# 4. Division
#
# -----
#
# *Columns which are NOT OK*
# 1. `Title` series has too many variations in writing the same thing - **we need to clean this column** (more on this in further sections)
# 2. `Highest Qualification Level` also requires multiple cleanups - for e.g. `Ph. D. ...`, `PhD.`, `Doctorate` etc., `Master of`, `Masters in` etc., mean the same things - **we need to clean this column** (more on this in further sections)
#
# -----
#
# *Columns which cannot be inspected at the moment (too many results)*
#
# `Highest Qualification`, `Major` `All Qualifications from Profile` have too many results to check individually - we need to apply other techniques for more efficient cleanups

# %% [markdown]
# #### Cleaning up 'Title' column
#
# Lets revisit the frequency count in title again

# %%
df['Title'].value_counts()
# Out:
# Faculty - Business                       252
# Faculty - Trainee                         13
# Adjunct Faculty - Business                 9
# Faculty- Business                          2
# Faculty - Business (Admin)                 1
# Graduate Trainee                           1
# Faculty - Business                         1
# Faculty - Business & Comp Lit.             1
# Faculty - Business & Comp Lit Faculty      1
# Business, Comp & Math Faculty              1
# Faculty-Business                           1
# Faculty-Business (HR & Admin.)             1
# Name: Title, dtype: int64

# %%
# Cleaning up a few things
df['Title'] = df['Title'].str.replace('Faculty- B', 'Faculty - B')
df['Title'] = df['Title'].str.replace('Faculty-B', 'Faculty - B')
df['Title'] = df['Title'].str.replace('Admin.', 'Admin', regex=False)
df['Title'] = df['Title'].str.replace('Admin', 'Administration', regex=False)
df['Title'] = df['Title'].str.replace('Comp Lit.', 'Comparative Literature', regex=False)
df['Title'] = df['Title'].str.replace('Comp Lit', 'Comparative Literature')
df['Title'] = df['Title'].str.replace('Comp & Math', 'Computing and Math')
df['Title'] = df['Title'].str.strip()
df['Title'].value_counts()
# Out:
# Faculty - Business                                     256
# Faculty - Trainee                                       13
# Adjunct Faculty - Business                               9
# Business, Computing and Math Faculty                     1
# Faculty - Business (Administration)                      1
# Graduate Trainee                                         1
# Faculty - Business & Comparative Literature Faculty      1
# Faculty - Business & Comparative Literature              1
# Faculty - Business (HR & Administration)                 1
# Name: Title, dtype: int64

# %% [markdown]
# From the above output, we still need to cleanup the titles - as the word **Faculty** can appear in the beginnning or at the end. Let us **remove the word Faculty** from the title, and store it in a separate column called **Title Prefix**

# %%
def filter_title(row):
    if check_is_empty(row['Title']):
        return None
    if 'adjunct faculty' in row['Title'].lower():
        return 'Adjunct Faculty'
    elif 'faculty' in row['Title'].lower():
        return 'Faculty'
    elif 'graduate trainee' in row['Title'].lower():
        return 'Graduate Trainee'
    else:
        return None
df['Title Prefix'] = df.apply(lambda row : filter_title(row), axis=1)

# Verify if any row is left out
temp_check = df[['Title', 'Title Prefix']]
temp_check[temp_check['Title Prefix'].isna()]
# Out:
# Empty DataFrame
# Columns: [Title, Title Prefix]
# Index: []

# %% [markdown]
# Its good that there is no row for which **Title Prefix** was not filled, now let's replace occurrence of **Faculty / Adjunct Faculty** or **Graduate Trainee** in title column with empty string

# %%
def title_cleanup(row):
    # Case insenstive replace with empty string
    row['Title'] = re.sub('adjunct faculty', '', row['Title'], flags=re.IGNORECASE)
    row['Title'] = re.sub('faculty', '', row['Title'], flags=re.IGNORECASE)
    row['Title'] = re.sub('graduate trainee', '', row['Title'], flags=re.IGNORECASE)
    # Replace all instances of '-' with empty string
    row['Title'] = row['Title'].replace('-', '')
    row['Title'] = row['Title'].strip()

df.apply(lambda row : title_cleanup(row), axis=1)
df['Title'].value_counts()
# Out:
# Business                             265
# Trainee                               13
# Business & Comparative Literature      2
#                                        1
# Business (Administration)              1
# Business (HR & Administration)         1
# Business, Computing and Math           1
# Name: Title, dtype: int64

# %% [markdown]
# **Optionally** - We could have further split the title values by **','** or **'&'** since:
# 1. `[Business, Computing and Math]` and `[Computing and Math, Business]` should be treated as same thing
# - To fix that, we could sort (ascending) the order in which terms appear
# 2. If `[Business (HR & Administration)]` could be further written like this - `[Business (Administration), Business (HR)]` so that ML analysis could derive partial similarity between this and `[Business (Administration)]`
#
# However, in the interest of time (and too low count to meaningfully affect current output) - we can **skip this step**.

# %% [markdown]
# #### Imputing 'Highest Qualification Level (HQL)' and 'Highest Qualification (HQ)'
#
# Let us analyse the **HQL - HQ** values below.

# %%
df.rename(columns = {'Highest Qualification Level':'HQL'}, inplace = True)
df.rename(columns = {'Highest Qualification':'HQ'}, inplace = True)
df.rename(columns = {'All Qualifications from Profile':'AQP'}, inplace = True)

temp_check = df[['HQL', 'HQ', 'AQP']]
temp_check[temp_check['HQL'].isna()]
# Out:
#      HQL   HQ                                                AQP
# 19   NaN  NaN  Post Graduate Diploma (Political Science), Mas...
# 99   NaN  NaN  Bachelor (Hospitality Management), Masters (Bu...
# 101  NaN  NaN            Masters (Finance), Bachelor (Economics)
# 245  NaN  NaN          Bachelor (Accounting), Masters (Business)
# 258  NaN  NaN  Masters (Finance), Bachelor (Accounting & Fina...
# 259  NaN  NaN  Bachelor (English Language & Literature), Mast...

# %% [markdown]
# No scope of imputation for HQL **from HQ**. We can, however, **impute certain values from AQP**. We will **revisit this imputation later**, when we analyze AQP in more detail.
#
# Below is the inverse of above - all rows where HQ is NA.

# %%
temp_check[temp_check['HQ'].isna()]
# Out:
#      HQL   HQ                                                AQP
# 19   NaN  NaN  Post Graduate Diploma (Political Science), Mas...
# 99   NaN  NaN  Bachelor (Hospitality Management), Masters (Bu...
# 101  NaN  NaN            Masters (Finance), Bachelor (Economics)
# 245  NaN  NaN          Bachelor (Accounting), Masters (Business)
# 258  NaN  NaN  Masters (Finance), Bachelor (Accounting & Fina...
# 259  NaN  NaN  Bachelor (English Language & Literature), Mast...

# %% [markdown]
# Same as before. As mentioned earlier, imputation of HQL and HQ **from AQP will be considered later** (after this section).
#
# As a last check, let's see if `len(HQL) > len(HQ)` for any row. This would imply that the data was mistakenly filled (swapped).

# %%
temp_check = df[(df['HQL'].str.len() > df['HQ'].str.len()) & (df['HQL'].str.lower() != 'doctorate')]
temp_check[['HQL', 'HQ']]
# Out:
#                                          HQL         HQ
# 72                  MBA in Banking & Finance        MBA
# 75            Doctor of Jurisprudence Degree  Doctorate
# 154     Ph.D in Organization and Management   Doctorate
# 243  PhD Corporate Governance and Accounting  Doctorate
# 263         Ph. D. (Business Administration)  Doctorate
# 274     Doctorate of Business Administration  Doctorate
# 277                         Ph.D (Economics)  Doctorate

# %% [markdown]
# Clearly, we can see that the values of HQL and HQ **have been swapped in multiple places**.

# %%
for idx in list(temp_check.index.values):
    swap_temp = df.loc[idx, 'HQ']
    df.at[idx, 'HQ'] = df.loc[idx, 'HQL']
    df.at[idx, 'HQL'] = swap_temp

df[['HQL', 'HQ']].iloc[list(temp_check.index.values)]
# Out:
#            HQL                                       HQ
# 72         MBA                 MBA in Banking & Finance
# 75   Doctorate           Doctor of Jurisprudence Degree
# 154  Doctorate     Ph.D in Organization and Management
# 243  Doctorate  PhD Corporate Governance and Accounting
# 263  Doctorate         Ph. D. (Business Administration)
# 274  Doctorate     Doctorate of Business Administration
# 277  Doctorate                         Ph.D (Economics)

# %% [markdown]
# #### Cleaning up 'HQL'
#
# Now, that the imputation is done (wherever possible), let's see if we can clean the column values. From the below data, we can do the following:
#
# 1. Any case-insensitive occurrence of `Ph.D`, `PhD`, `Ph. D.`, `PhD.`, `Doctor of`, `Doctorate of` can be labelled as Doctorate.
# 2. **After Step 1** - Any case-insensitive occurence of `Masters`, `Master`, `MBA` can be labelled as Masters. Note: Its important to note that for the purposes of this ML system, **MBA is treated equivalent to Masters.**
# 3. **After Step 2** - Any case-insensitive occurence of `Bachelor`, `Bachelors` can be labelled as Bachelor.

# %%
df['HQL'].value_counts()
# Out:
# Masters                                                                     157
# Doctorate                                                                    58
# Ph.D                                                                         43
# Bachelor                                                                     12
# MBA                                                                           2
# Bachelor (Applied Science) in Business administration( Human Resources )      1
# Master of International Business                                              1
# Maters of Philosophy (Economics)                                              1
# Master of Business Administration (MBA) and MA (Economics)                    1
# Masters (Business Administration), Master of Philosophy (Business)            1
# Master's Degree in Public Relations and Press Office Management               1
# Name: HQL, dtype: int64

# %%
# Occurrences of the values on the left, will be replaced with the key on the right
replace_map = {
    'T_D' : ['phd.', 'ph.d.', 'ph.d', 'ph. d.', 'ph. d', 'phd', 'doctorate', 'doctor'],
    'T_M' : ['masters', "master's", 'master of', 'master', 'mba', 
                   # this is to fix a typo in the TSV
                   'maters'],
    'T_B' : ['bachelors', 'bachelor']
}
final_value_map = {
    'T_D' : 'Doctorate',
    'T_M' : 'Masters',
    'T_B' : 'Bachelor'
}
def hql_cleanup(row):
    # replacement in order
    for key in ['T_D', 'T_M', 'T_B']:
        values = replace_map[key]
        for value in values:
            if check_is_not_empty(row['HQL']) and value in row['HQL'].lower():
                row['HQL'] = key
    
    if check_is_not_empty(row['HQL']):
        row['HQL'] = final_value_map[row['HQL']]

df.apply(lambda row : hql_cleanup(row), axis=1)
df['HQL'].value_counts()
# Out:
# Masters      164
# Doctorate    101
# Bachelor      13
# Name: HQL, dtype: int64

# %% [markdown]
# #### Cleaning up 'Highest Qualification'
#
# From the below output, we can observe some general cleanups
# 1. `Ph.D`, `PhD.` etc could be merged to a single representation (similar to what was done for HQ)
# 2. `Master`, `Masters`, `Mast` etc in the qualification names should be merged to a single representation
# 3. `Administrat` should be renamed to `Administration` (and fixing typos like `administrationion`)
# 4. All names could be `lowercased` to remove differences
# 5. Replace cells which are just Ph.D or Masters with `na`. This is because, the information is already encapsulated in `HQL` columm. This provides no additional value.
# 6. However, we will preserve single letter values like `MBA` (Masters in Business Administration) and `MA` (Master of Arts) as they provide extra info.
# 7. `of`, `Of` or `in`, `In` cause differences at string level. It would be good if we can think of better representation - which overlooks differences in adverbs/adjectives. For example, a **comma separated tuple representation - (Qualification, Course)** could be more meaningful. In code, we tupulize it to `(Qualification$$Course)` as it is easy to split later on

# %%
df['HQ'] = df['HQ'].str.strip()
df['HQ'].value_counts()
# Out:
# Master of Business Administrat                                              73
# Ph.D                                                                        63
# Master of Science                                                           18
# Masters                                                                     17
# Master of Commerce                                                           9
#                                                                             ..
# Ph.D In Accounting                                                           1
# MBA                                                                          1
# Bachelor (Applied Science) in Business administration( Human Resources )     1
# Master of International Business                                             1
# MA in Teaching                                                               1
# Name: HQ, Length: 66, dtype: int64

# %%
# Occurrences of the values on the left, will be replaced with the key on the right
replace_map = {
    'T_P' : ['phd.', 'ph.d.', 'ph.d', 'ph. d.', 'ph. d', 'phd', 'doctorate', 'doctor of'],
    'T_M' : ['masters', "master's", 'master', 'mast', 'mba'],
    'T_B' : ['bachelors', 'bachelor'],
    'T_MB' : ['mba']
}

def basic_replacements(row, col_key):
        for key, values in replace_map.items():
            for value in values:
                if check_is_not_empty(row[col_key]):
                    row[col_key] = row[col_key].lower().replace(value, key.lower())

        # Other cleanup(s)
        if check_is_not_empty(row[col_key]):
            row[col_key] = row[col_key].replace('administrat', 'administration')
            row[col_key] = row[col_key].replace('administrationion', 'administration')
            row[col_key] = row[col_key].replace('admin.', 'administration')
            
def hq_tupulizer(col_key):
    df.apply(lambda row : basic_replacements(row, col_key), axis=1)

    # Replace cells containing ONLY 1 word - t_p, t_m, etc.
    df.replace(r"\bt_p$\b", np.nan, regex=True, inplace=True)
    df.replace(r"\bt_m$\b", np.nan, regex=True, inplace=True)
    df.replace(r"\bt_b$\b", np.nan, regex=True, inplace=True)
    # Replace cells containing ONLY 1 word and 'in' or 'of' - t_p, t_m, etc.
    df.replace(r"\bt_p\s+(of|in)$\b", np.nan, regex=True, inplace=True)
    df.replace(r"\bt_m\s+(of|in)$\b", np.nan, regex=True, inplace=True)
    df.replace(r"\bt_b\s+(of|in)$\b", np.nan, regex=True, inplace=True)
    
    # Note: we are leaving single word cells with `ma`, `t_mb` as it is ^

    # Convert data into a tuple-like represenation (Level$$Qualification)
    df[col_key].replace(
        {r'\b(t_p|t_mb|t_b|t_m|ma)\s+(of\s|in\s)?\(?([\w|\s|&|/]*)\)?' : r'(\1$$\3)'}, 
        regex=True, 
        inplace=True
    )
    
    # Replace empty spaces after '(' or before ')'
    df[col_key].replace(
        {r'(?<=[([]) +| +(?=[)\]])' : ''}, 
        regex=True, 
        inplace=True
    )

hq_tupulizer('HQ')
df['HQ'].value_counts()
# Out:
# (t_m$$business administration)                                        73
# (t_m$$science)                                                        18
# (t_p$$business administration)                                        10
# (t_b$$applied science)                                                 9
# (t_m$$commerce)                                                        9
# (t_m$$arts)                                                            7
# (t_p$$economics)                                                       4
# (t_p$$philosophy)                                                      4
# (t_m$$philosophy)                                                      4
# (t_m$$management)                                                      3
# (ma$$international business)                                           3
# (t_p$$accounting)                                                      2
# (t_m$$law)                                                             2
# (t_m$$business)                                                        2
# (t_m$$education)                                                       2
# (t_p$$economic sciences)                                               1
# (t_p$$education and human resources studies)                           1
# (t_m$$business administration), (t_m$$philosophy)(business)            1
# (t_m$$banking & finance)                                               1
# (t_m$$quality management)                                              1
# (t_p$$organization and management)                                     1
# (t_m$$degree in public relations and press office management)          1
# (t_m$$applied finance)                                                 1
# (t_p$$management sciences)                                             1
# (t_m$$distance education)                                              1
# (t_m$$business administration)(t_m) and (ma$$economics)                1
# (ma$$teaching)                                                         1
# (t_p$$public policy and administration)                                1
# (t_m$$engineering)                                                     1
# (t_p$$jurisprudence degree)                                            1
# (t_p$$middle eastern and islamic studies)                              1
# (t_p$$marketing)                                                       1
# (t_p$$education)                                                       1
# (t_m$$strategic hr mgmt).                                              1
# (t_m$$international business)                                          1
# (t_p$$corporate governance and accounting)                             1
# (t_b$$business administration)                                         1
# economics and business                                                 1
# maters of philosophy (economics)                                       1
# (t_b$$applied science) in business administration(human resources)     1
# (ma$$accounting)                                                       1
# (t_m$$professional studies)                                            1
# (t_p$$management)                                                      1
# (t_b$$science)                                                         1
# international business &market                                         1
# (t_p$$hrm/ organizational pyschology)                                  1
# (t_p$$business management)                                             1
# management science                                                     1
# (t_m$$marketing)                                                       1
# (t_m$$education technology)                                            1
# (t_p$$economics and international business)                            1
# (t_p$$business admin)                                                  1
# Name: HQ, dtype: int64

# %% [markdown]
# ##### Few notes from above output -
#
# 1. We didn't gain a very high advantage in consolidating outputs, but **atleast** we can easily see the outliers now - which have incorrect pattern
# 2. For example - `(t_m$$business administration )(t_m) and (ma$$economics)` has two qualifications - which is wrong
# 3. Some entries like `international business &market`, `management science` don't specify the level.
# 4. We **can write a more complex logic** for preserving the second half in entries like -
# ```
# Bachelor (Applied Science) in Business administration( Human Resources )   --> (t_b$$applied science) in business administration(human resources)
# ```
# However, to keep it in common with other entries like `(t_b$$applied science)` - we don't process it further
#
#
# **Also, note that** - `(t_m$$arts)` and `ma`  ... or `(t_m$$business administration)` and `mba` can be considered equivalent and replaced. (This equivalence however, is not implemented for now)
#
# ---
#
# Finally, lets clean and replace the values not matching with our pattern `(Level$$Qualification)` with `na`

# %%
hq_search_regex = '\((t_p|t_mb|t_b|t_m|ma)\$\$[\w|\s|&|/]+\)'
def hq_cleaner(row, col_key):
    if check_is_not_empty(row[col_key]):
        temp_str = row[col_key]
        search = re.search(hq_search_regex, temp_str)
        result = search.group(0) if search else ''  # by default, we will only consider the first matching group 
        # - as this column should contain a single qualification
        row[col_key] = result.strip()

df.apply(lambda row : hq_cleaner(row, 'HQ'), axis=1)
# Replace cells with empty string with NA
df.replace(r'^\s*$', np.NaN, regex=True, inplace=True)
df['HQ'].value_counts()
# Out:
# (t_m$$business administration)                                   75
# (t_m$$science)                                                   18
# (t_p$$business administration)                                   10
# (t_b$$applied science)                                           10
# (t_m$$commerce)                                                   9
# (t_m$$arts)                                                       7
# (t_m$$philosophy)                                                 4
# (t_p$$philosophy)                                                 4
# (t_p$$economics)                                                  4
# (t_m$$management)                                                 3
# (ma$$international business)                                      3
# (t_m$$business)                                                   2
# (t_p$$accounting)                                                 2
# (t_m$$law)                                                        2
# (t_m$$education)                                                  2
# (t_m$$applied finance)                                            1
# (t_p$$hrm/ organizational pyschology)                             1
# (t_p$$business management)                                        1
# (t_m$$strategic hr mgmt)                                          1
# (t_m$$degree in public relations and press office management)     1
# (t_b$$business administration)                                    1
# (t_m$$marketing)                                                  1
# (t_p$$public policy and administration)                           1
# (t_m$$international business)                                     1
# (t_p$$education and human resources studies)                      1
# (t_m$$banking & finance)                                          1
# (t_m$$engineering)                                                1
# (t_p$$middle eastern and islamic studies)                         1
# (t_m$$professional studies)                                       1
# (t_p$$corporate governance and accounting)                        1
# (t_p$$marketing)                                                  1
# (t_p$$business admin)                                             1
# (t_p$$economic sciences)                                          1
# (t_m$$quality management)                                         1
# (ma$$accounting)                                                  1
# (t_m$$distance education)                                         1
# (t_b$$science)                                                    1
# (ma$$teaching)                                                    1
# (t_p$$jurisprudence degree)                                       1
# (t_p$$management sciences)                                        1
# (t_m$$education technology)                                       1
# (t_p$$economics and international business)                       1
# (t_p$$education)                                                  1
# (t_p$$organization and management)                                1
# (t_p$$management)                                                 1
# Name: HQ, dtype: int64

# %% [markdown]
# #### Data Wrangling AQL
#
# A similar approach (like HQ) needs to followed to **structurize the qualifications**, in the form of a set like:
#
# ```
# {(t_b$$business administration), (t_b$$applied science), ..}
# ```
#
# This set could be even **used for data imputation of HQL and HQ!**. We can simply sort the set by qualification prefixes t_b, t_m/t_mb/ma, t_p in order (lowest to highest) and find the highest level as well as the subject.
#
# However, in the interest of time, I am skipping the code implementation for the same.

# %% [markdown]
# #### Data Wrangling the "DOCUMENT OTHER ... " column
#
# Let's take a sneak peak from this column

# %%
df.rename(columns={
        'DOCUMENT OTHER PROFESSIONAL CERTIFICATION CRITIERA Five Years Work Experience '
        'Teaching Excellence Professional Certifications': 'OtherDoc'}, inplace=True
)

print(df['OtherDoc'].head(10))
# Out:
# 0    10+ Years Small Business Ownership, 10+ Years ...
# 1    years of teaching experience: 17              ...
# 2    Years of teaching experience: 15 Years of prof...
# 3    6 years professional experience + 6 years teac...
# 4    1 year professional experience + 24 years teac...
# 5                                                  NaN
# 6                                                  NaN
# 7                         11 years teaching experience
# 8    7+ years Teaching/Corporate Training experienc...
# 9    Taught 1 business course (1 semester)  Have be...
# Name: OtherDoc, dtype: object

# %% [markdown]
# Its clear that there is no specific structure - and a simple regex won't be sufficient. We could however, try to make a rough **phrase-tokeniser by multiple regex's or some carefully selected separators**. By **phrase-tokens**, I mean small meaningful sentences like `Years of teaching experience: 17`.

# %%
separators = [
    {'name': 'comma', 'regex': False, 'separator': ','},
    {'name': 'semi_colon', 'regex': False, 'separator': ';'},
    {'name': 'dot', 'regex': False, 'separator': '.'},
    {'name': 'tab', 'regex': False, 'separator': '\t'},
    {'name': 'plus', 'regex': False, 'separator': '+'},
    {'name': 'newline', 'regex': False, 'separator': '\n'},
    {'name': 'slash', 'regex': False, 'separator': '/'},
    {'name': 'and', 'regex': False, 'separator': 'and'},
    {'name': 'ampersand', 'regex': False, 'separator': '&'},
    # all regexes below split by capture groups
    {'name': 'regex_1', 'regex': True, 'separator': r'(?i)(.*?experience:\s?\d+)'},
    {'name': 'regex_1', 'regex': True, 'separator': r'(?i)(\d+\s+(years|yrs|year|yr)\s+prof.*?experience)'},
    {'name': 'regex_1', 'regex': True, 'separator': r'(?i)(\d+\s+(years|yrs|year|yr)\s+teaching\s(and\s.*?researcher)?)'},
    {'name': 'regex_2', 'regex': True, 'separator': r'(?i)(\d+.+?(years|yrs|year|yr).+?experience)'},
    {'name': 'regex_2', 'regex': True, 'separator': r'(?i)(.*work experience)\s?and(.*teaching)'},
    {'name': 'regex_3', 'regex': True, 'separator': r'(?i).*?(part time.*)'},
    {'name': 'regex_4', 'regex': True, 'separator': r'(?i)(^(?!,).*(certificate|certification).*(,|;))'},
    {'name': 'regex_5', 'regex': True, 'separator': r'(?i)(,|;)(\s+.*(certificate|certification).*)'},
    {'name': 'regex_whitespace_2+', 'regex': True, 'separator': r'(?:\s{2,})'},
    {'name': 'regex_whitespace_3+', 'regex': True, 'separator': r'(?:\s{3,})'}
]

def phrase_tokenizer(row):
    row_value = row['OtherDoc']
    phrase_tokenize_result = []
    
    if check_is_not_empty(row_value):
        separator_wise_splits = {}
        for separator in separators:
            if not separator['regex']:
                separator_wise_splits[separator['name']] = {
                    'split_values': row_value.split(separator['separator'])
                }
            else:
                separator_wise_splits[separator['name']] = {
                    'split_values': re.split(separator['separator'], row_value)
                }
        
        return {'separator_wise_splits': separator_wise_splits}
        

# Lets see the results
temp_check = df[['OtherDoc']].copy(deep=True)
temp_check['PhraseTokens'] = temp_check.apply(lambda row : phrase_tokenizer(row), axis=1)
for idx, rw in temp_check[temp_check['OtherDoc'].str.contains('experience', na = False)].sample(1).iterrows():
    print(rw['OtherDoc'])
    print(json.dumps(rw['PhraseTokens'], indent=2, sort_keys=True))
    print('------')
# Out:
# years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer
# {
#   "separator_wise_splits": {
#     "ampersand": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "and": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public ",
#         " Certified Conveyancer          "
#       ]
#     },
#     "comma": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney",
#         " Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "dot": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "newline": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "plus": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "regex_1": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "regex_2": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "regex_3": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "regex_4": {
#       "split_values": [
#         "",
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney,",
#         "Certification",
#         ",",
#         " Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "regex_5": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "regex_whitespace_2+": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer",
#         ""
#       ]
#     },
#     "regex_whitespace_3+": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer",
#         ""
#       ]
#     },
#     "semi_colon": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "slash": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional",
#         "management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     },
#     "tab": {
#       "split_values": [
#         "years of teaching experience: 8 years of professional/management experience: 12 Professional Certification: Certified Attorney, Certified Notary Public and Certified Conveyancer          "
#       ]
#     }
#   }
# }
# ------

# %% [markdown]
# In the above output, we can observe that some trial and error with regexes ... we are able to catch sub-phrases by some of the **separator** styles. (Note: Since sampling is random in the above statement, results will differ everytime the code is run)
#
# Now, the problem is to weed out the values which are not split, or split uncleanly.
#
# For this we can write a sanitizer, using some guesses and approximations.
#
# 1. Remove all results below a specific length (Initially we start with 10 .. we can adjust this through trial and error)
# 2. Remove all results above a specific lenght (Initially we start with 100 .. we can adjust this through trial and error)
# 3. Replace `.`, `+`, 'plus`, ':`, `;` with empty string (we don't need stopwords inside phrase-tokens
# 4. Convert presence of "word-numbers" to numeric representation. For example - "Nine years of teaching experience" would be converted to "9 years of teaching experience"
# 5. [After step 3] Strip out all the numbers from the phrase-tokens and put them in a separate list. We intend to cluster common results together. Having numerical values would cause unneccessary variance.
# 6. Remove all instances of multiple whitespaces like `  ` with a single whitespace.
# 7. Deduplicate splits (phrase-tokens) if multiple separators have given the same output

# %%
from utils.text_to_num import text2int

def phrase_token_sanitizer(row):
    row_value = row['PhraseTokens']
    deduplicated_phrases = set()
    if check_is_not_empty(row_value):
        for separator_type, separated_phrases in row_value['separator_wise_splits'].items():
            cleaned_phrases = []
            cleaned_phrases_numerics = []
            for phrase in separated_phrases['split_values']:
                if not phrase:
                    continue
                if len(phrase) <= 10:
                    # 10 is the length of the string '100+ Years'
                    # Too small token to be meaningful
                    continue
                if len(phrase) >= 100:
                    # To err on the safer side, we assume the splitting was unclean (adjust by trial and error)
                    continue

                # Before mutating the selected phrase, we should ideally STORE this - to perform later analysis
                # on which part of the original string WAS NOT selected ..
                # .. (by subtracting selected phrase from the original string)
                phrase = phrase.replace('.', '')
                phrase = phrase.replace(',', '')
                phrase = phrase.replace('+', '')
                phrase = phrase.replace('plus', '')
                phrase = phrase.replace(':', '')
                phrase = phrase.replace(';', '')
                # Replace multiple whitespaces with a single whitespace
                phrase = ' '.join(phrase.split())
                phrase = phrase.strip()

                if phrase:
                    # Convert 'word-numbers' to actual decimal numbers
                    phrase = text2int(phrase)

                    # Replace all numbers by the placeholder 'n_u_m'
                    numerics = re.findall(r'(\d+)', phrase)
                    phrase = re.sub(r'(\d+)', 'n_u_m', phrase)

                    cleaned_phrases_numerics.append(numerics)
                    cleaned_phrases.append(phrase)
                    deduplicated_phrases.add(phrase)

            separated_phrases['split_values'] = cleaned_phrases
            separated_phrases['phrases_numerics'] = cleaned_phrases_numerics

    return deduplicated_phrases


temp_check['CleanedPhraseSet'] = temp_check.apply(lambda row: phrase_token_sanitizer(row), axis=1)
# Lets see the results
for idx, rw in temp_check[temp_check['OtherDoc'].str.contains('experience', na = False)].sample(4).iterrows():
    print('Original String: ' + rw['OtherDoc'] + '\n')
    print('Extracted Phrase Tokens: ' + str(rw['CleanedPhraseSet']))
    print('------')
# Out:
# Original String: 15 years of  professional work in education and business areas;  5  years of  teaching experience
#
# Extracted Phrase Tokens: {'n_u_m years of teaching experience ', 'n_u_m years of professional work in education and business areas ', 'teaching experience ', 'professional work in education and business areas ', 'n_u_m years of professional work in education ', 'n_u_m years of professional work in education and business areas n_u_m years of teaching experience ', 'n_u_m years of ', 'business areas n_u_m years of teaching experience '}
# ------
# Original String: years teaching experience: 10+ management experiece-5 years
#
# Extracted Phrase Tokens: {'years teaching experience n_u_m', 'years teaching experience n_u_m management experiece n_u_m years ', 'management experiece n_u_m years '}
# ------
# Original String: EFQM ISO 9001 Internal Auditor, EFQM ISO 9001 External Auditor, 24 years teaching experience
#
# Extracted Phrase Tokens: {'EFQM ISO n_u_m Internal Auditor EFQM ISO n_u_m External Auditor n_u_m years teaching experience ', 'EFQM ISO n_u_m External Auditor ', 'n_u_m years teaching ', 'EFQM ISO n_u_m Internal Auditor EFQM ISO n_u_m External Auditor ', 'n_u_m years teaching experience ', 'EFQM ISO n_u_m Internal Auditor '}
# ------
# Original String: 16 years professional( consulting) experience + 19 years teaching and active researcher. Curriculum development  and research publishing experience
#
# Extracted Phrase Tokens: {'n_u_m years professional( consulting) experience n_u_m years teaching and active researcher ', 'n_u_m years professional( consulting) experience ', 'active researcher Curriculum development ', 'n_u_m years teaching and active researcher ', 'n_u_m years professional( consulting) experience n_u_m years teaching ', 'Curriculum development and research publishing experience ', 'and active researcher ', 'and research publishing experience ', 'research publishing experience '}
# ------

# %% [markdown]
# #### k-Means clustering
#
# (Note: Since sampling is random in the above statement, results will differ everytime the code is run)
#
# The above output looks much better now.
#
# On to the next step: lets run k-means clustering and see if we are able to find some cleanly separated clusters
#
# To run k-means, we need to first vectorize the phrases. k-Means clusterises by distance (euclidean distance) - and hence the notion of a vector - every data point represented as a vector, allows for euclidean calculation between data points.
#
# For vectorising, we will use the "bag of words" approach. We will count the occurences of a particular word in a phrase, and use that for vector representation.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Build a super list
cleaned_phrase_sets = temp_check['CleanedPhraseSet'].tolist()
cleaned_phrases_all = list()
for set_item in cleaned_phrase_sets:
    for item in set_item:
        cleaned_phrases_all.append(item)

# Pass the list to the word vectorizer
vectorizer = CountVectorizer()
features = vectorizer.fit_transform(cleaned_phrases_all).todense()
print(vectorizer.vocabulary_)
# Out:
# {'n_u_m': 273, 'years': 434, 'small': 362, 'business': 63, 'ownership': 296, 'vocational': 421, 'training': 401, 'teaching': 384, 'experience': 150, 'corporate': 101, 'sme': 363, 'consulting': 96, 'of': 289, 'professional': 321, 'management': 253, 'certification': 75, 'gcma': 170, 'acma': 13, 'and': 27, 'active': 14, 'researcher': 338, 'accreditation': 11, 'background': 45, 'year': 433, 'curriculum': 110, 'development': 121, 'certified': 78, 'trainer': 400, 'taught': 382, 'course': 103, 'semester': 349, 'have': 183, 'been': 53, 'doing': 123, 'shadowing': 356, 'observation': 286, 'for': 161, 'now': 284, 'in': 209, 'senior': 351, 'roles': 343, 'higher': 186, 'education': 131, 'months': 270, 'work': 426, 'isw': 232, 'train': 398, 'the': 392, 'fdw': 157, 'icdl': 198, 'excellence': 143, 'award': 44, 'twice': 404, 'institutions': 222, 'more': 271, 'than': 391, 'chartered': 84, 'secretary': 346, 'industry': 214, 'universities': 411, 'colleges': 91, 'socio': 365, 'economic': 127, 'research': 337, 'areas': 30, 'part': 297, 'time': 394, 'on': 292, 'various': 416, 'departments': 117, 'banks': 50, 'university': 412, 'practical': 311, 'banking': 49, 'exerience': 146, 'as': 31, 'visiting': 419, 'faculty': 154, 'full': 166, 'licensed': 246, 'to': 395, 'practice': 312, 'law': 238, 'graduate': 177, 'tertiary': 390, 'learning': 242, 'admitted': 16, 'bar': 51, 'british': 59, 'columbia': 92, 'canada': 67, 'hospitality': 191, 'educator': 133, 'american': 23, 'hotleirs': 192, 'lodging': 249, 'association': 36, 'media': 262, 'marketing': 257, 'n_u_myears': 277, 'hr': 193, 'uae': 405, 'fdp': 156, 'iim': 206, 'ahmedabad': 20, 'bsi': 60, 'middle': 267, 'east': 125, 'pmp': 306, 'iso': 230, 'trained': 399, 'tafe': 380, 'certificate': 74, 'iv': 234, 'btec': 61, 'advanced': 18, 'diploma': 122, 'executive': 144, 'hrm': 195, 'cert': 73, 'classroom': 87, 'assessment': 32, 'icn_u_m': 201, 'teachers': 383, 'norton': 282, 'balanced': 47, 'scorecard': 345, 'strategy': 371, 'implementation': 208, 'kaplan': 236, 'islamic': 229, 'finance': 158, 'post': 308, 'cerificate': 72, 'educatiion': 130, 'uk': 407, 'member': 263, 'academy': 4, 'efqm': 135, 'internal': 225, 'auditor': 39, 'external': 153, 'pgce': 300, 'fahe': 155, 'celta': 71, 'profesional': 319, 'institute': 220, 'leadership': 241, 'cpa': 104, 'ii': 204, 'cps': 105, 'iii': 205, 'qualifications': 330, 'an_u_m': 25, 'assessor': 34, 'qualification': 329, 'edexcel': 129, 'ma': 251, 'mba': 259, 'accounting': 9, 'ed': 128, 'educationn_u_m': 132, 'australia': 40, 'pcet': 298, 'vn_u_m': 420, 'conducting': 95, 'quality': 332, 'assurance': 37, 'process': 315, 'ocr': 287, 'academic': 3, 'institutional': 221, 'ugc': 406, 'net': 279, 'india': 211, 'planning': 305, 'delivering': 113, 'irb': 227, 'instructional': 223, 'skills': 361, 'workshops': 430, 'blended': 56, 'online': 293, 'instructor': 224, 'project': 326, 'supply': 375, 'chain': 82, 'takaful': 381, 'uyears': 415, 'global': 173, 'six': 360, 'sigma': 358, 'working': 427, 'notary': 283, 'public': 327, 'conveyancer': 98, 'green': 179, 'belt': 54, 'commercial': 93, 'cap': 69, 'ttw': 403, 'ftw': 164, 'isalmic': 228, 'cma': 88, 'exams': 142, 'aviation': 43, 'analyst': 26, 'many': 256, 'certifications': 76, 'mainly': 252, 'oil': 291, 'gas': 168, 'equis': 137, 'grant': 178, 'writing': 432, 'reserach': 339, 'aacsb': 0, 'accreditaion': 10, 'hrd': 194, 'curricula': 109, 'design': 119, 'reporting': 336, 'lead': 239, 'associate': 35, 'icma': 200, 'icsa': 202, 'singapore': 359, 'exp': 147, 'mgmt': 266, 'prof': 318, 'tqm': 396, 'supervisory': 374, 'acfe': 12, 'us': 413, 'from': 163, 'cambridge': 66, 'expirience': 152, 'oracle': 294, 'yrs': 435, 'pgcthe': 301, 'experiece': 149, 'cim': 85, 'ethics': 139, 'dba': 112, 'abd': 1, 'webmaster': 423, 'beverage': 55, 'seminar': 350, 'september': 353, 'october': 288, 'holiday': 188, 'inn': 216, 'general': 171, 'may': 258, 'food': 160, 'inns': 219, 'tecahing': 387, 'college': 90, 'manager': 254, 'sphr': 367, 'n_u_mv': 275, 'workplace': 428, 'p ...

# %%
# Executing k-means
from sklearn.cluster import KMeans

_cluster_size = 8

km = KMeans(
    n_clusters=_cluster_size, init='random',
    n_init=12, max_iter=10000,
    tol=1e-04, random_state=0
)
labels = km.fit_predict(features)

# To evaluate output, lets create a data-frame with "phrase" and "cluster" together
cluster_map = pd.DataFrame(
    {
        "sentences": cleaned_phrases_all,
        "cluster": km.labels_
    }
)

# Display the output
print("Cluster\t\tSentence")
for index, row in cluster_map.iterrows():
    print(str(row['cluster']) + '\t\t' + str(row['sentences']))
# Out:
# Cluster		Sentence
# 7		n_u_m Years Small Business Ownership
# 7		Vocational Business Training n_u_m Years Teaching Experience
# 7		Years Small Business Ownership n_u_m
# 7		n_u_m Years Corporate/Vocational Business Training
# 3		n_u_m Years Small Business Ownership n_u_m Years SME Consulting n_u_m Years Corporate
# 7		Years Corporate/Vocational Business Training n_u_m Years Teaching Experience
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 7		n_u_m years teaching exerience as a visiting faculty
# 7		n_u_m years teaching
# 6		experience as a full time faculty and
# 5		n_u_m years corporate experience
# 6		exerience as a visiting faculty
# 2		licensed to practice law Graduate Certification in Tertiary Teaching and Learning
# 7		n_u_m years teaching
# 7		Learning n_u_m years teaching experience
# 6		Certification
# 7		n_u_m years teaching experience
# 6		Admitted to the Bar of British Columbia Canada licensed to practice law
# 6		Admitted to the Bar of British Columbia
# 2		Graduate Certification in Tertiary Teaching and Learning n_u_m years teaching experience
# 6		Certified Hospitality Educator(American Hotleirs and Lodging Association)
# 6		media marketing
# 2		n_u_myears experience in Corporate HR and media marketing
# 6		Certified Hospitality Educator(American Hotleirs and Lodging Association) n_u_m
# 6		Certified Hospitality Educator(American Hotleirs
# 2		n_u_myears experience in Higher education in UAE
# 6		certified FDP IIM ahmedabad BSI middle east
# 7		PMP certified FDP IIM ahmedabad BSI middle east ISO trained n_u_m years teaching experience
# 6		PMP certified
# 7		ISO trained n_u_m years teaching experience
# 7		n_u_m years teaching
# 6		FDP IIM ahmedabad
# 6		experience
# 6		PMP certified FDP IIM ahmedabad BSI middle east ISO trained
# 7		n_u_m years teaching experience
# 6		BSI middle east ISO trained
# 6		TAFE Certificate IV in Training
# 7		n_u_m years teaching
# 6		BTEC Advanced Professional Diploma in Executive HRM
# 6		Cert in Advanced Classroom Assessment
# 6		TAFE Certificate IV in Training and Assessment ICn_u_m
# 6		Certificate
# 0		Professional Teachers' Certificate More than n_u_m years teaching experience
# 6		in Advanced Classroom Assessment Professional Teachers' Certificate
# 0		More than n_u_m years teaching experience
# 6		TAFE Certificate IV in Training and Assessment
# 6		Norton Balanced Scorecard Certificate in Strategy Management and Implementation
# 2		Graduate Certificate in Teaching and Learning
# 2		Graduate Certificate in Teaching and Learning Kaplan
# 6		Kaplan & Norton Balanced Scorecard Certificate in Strategy Management and Implementation
# 2		Graduate Certificate in Teaching
# 6		Learning Kaplan & Norton Balanced Scorecard Certificate in Strategy Management
# 6		Certificate
# 6		Implementation
# 6		Certificate in Islamic Finance
# 7		n_u_m years teaching
# 2		Certificate in Islamic Finance n_u_m years teaching experience
# 6		Certificate
# 7		n_u_m years teaching experience
# 7		n_u_m years teaching
# 7		n_u_m years teaching experience
# 6		Industry experience
# 5		experience n_u_m years
# 3		Industry experience n_u_m years Teaching experience n_u_m years
# 5		Industry experience n_u_m years
# 7		Teaching experience n_u_m years
# 7		n_u_m years Teaching
# 6		Post Graduate Cerificate in Educatiion (UK)
# 6		Member of Higher Education Academy
# 2		Post Graduate Cerificate in Educatiion (UK) Member of Higher Education Academy
# 2		experience Post Graduate Cerificate in Educatiion (UK) Member of Higher Education Academy
# 7		n_u_m years teaching
# 7		n_u_m years teaching experience
# 7		n_u_m years teaching
# 7		n_u_m years teaching experience
# 5		n_u_m years industry experience
# 5		experience and n_u_m years industry experience
# 3		n_u_m years teaching experience and n_u_m years industry experience
# 7		n_u_m years teaching
# 7		n_u_m years teaching experience
# 7		years of teaching experience
# 7		n_u_m years of teaching experience
# 3		EFQM ISO n_u_m Internal Auditor EFQM ISO n_u_m External Auditor n_u_m years teaching experience
# 6		EFQM ISO n_u_m External Auditor
# 7		n_u_m years teaching
# 7		EFQM ISO n_u_m Internal Auditor EFQM ISO n_u_m External Auditor
# 7		n_u_m years teaching experience
# 6		EFQM ISO n_u_m Internal Auditor
# 7		years teaching experience
# 7		n_u_m years teaching experience
# 7		n_u_m years teaching
# 6		PGCE FAHE CELTA
# 6		Management
# 6		Certification
# 7		PGCE FAHE CELTA n_u_m years teaching Experience
# 6		Profesional Certification Member of the Institute of Leadership and Management
# 6		CPA II and CPS III professional qualifications
# 6		An_u_m Assessor qualification (Edexcel UK)
# 6		MA Management and Leadership Practice MBA Accounting and Finance
# 7		B Ed Business Educationn_u_m years teaching experience
# 6		MA Management
# 6		CPS III professional qualifications Certificate IV in Training
# 6		Certificate IV in Training and Assessment (Australia)
# 7		n_u_m years teaching
# 6		PGCE (PCET)
# 6		Leadership Practice MBA Accounting
# 6		Certificate
# 6		MBA Accounting and Finance
# 6		MA Management and Leadership Practice
# 6		Vn_u_m Certificate n_u_m Conducting Internal Quality Assurance of Assessment Process (OCR)
# 6		Member Institute for Learning (UK)
# 6		Academic Teaching
# 2		(n_u_m years experience in Institutional Marketing
# 2		years experience in Institutional Marketing Corporate Training and Academic Teaching
# 6		UGC NET (India)
# 6		Edexcel (UK) Professional Certificate in Planning and Delivering Vocational Qualifications
# 6		Certificate
# 6		Corporate Training and Academic Teaching
# 6		Edexcel (UK) Professional Certificate in Planning
# 7		PGCE n_u_m years teaching experience
# 7		n_u_m years teaching
# 7		n_u_m years teaching experience
# 7		n_u_m years teaching
# 6		ICDL IRB Instructional Skills Workshops (ISW) Blended online Instructor Training
# 5		Experience n_u_m years Industry Experience
# 7		n_u_m years teaching
# 7		n_u_m years teaching experience
# 6		ISO n_u_m Internal Auditor
# 7		n_u_m years teaching
# 5		ISO n_u_m Internal Auditor Project Management Professional Certification
# 6		Certification
# 7		n_u_m years teaching experience
# 6		Project Management Professional Certification
# 5		experience ISO n_u_m Internal Auditor Project Management Professional Certification
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years professional experience n_u_m years teaching and active researcher
# 5		n_u_m years professional experience
# 6		and active researcher
# 6		active researcher
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years professional experience n_u_m years teaching and active researcher
# 5		n_u_m years professional experience
# 6		and active researcher
# 6		active researcher
# 5		n_u_m years Professional experience
# 7		n_u_m years teaching
# 3		n_u_m years Professional experience n_u_m years teaching
# 7		n_u_m years Teaching Experience
# 7		n_u_m years Teaching Experience active researcher
# 6		Experience active researcher
# 6		active researcher
# 7		n_u_m years Teaching
# 5		n_u_m years Professional experience
# 7		n_u_m years teaching
# 3		n_u_m years Professional experience n_u_m years teaching
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 6		Certificate in Supply chain
# 3		n_u_m years professional experience n_u_m years teaching
# 6		Certificate Takaful Professional
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 6		Certificate
# 6		Certificate Takaful Professional Certificate in Supply chain
# 3		n_u_m years professional experience n_u_m years teaching and Curriculum development
# 5		n_u_m years Professional experience
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years Professional experience n_u_m years teaching and active researcher
# 6		and active researcher
# 6		active researcher
# 3		n_u_m years Professional experience n_u_m years teaching
# 5		management experience n_u_m
# 4		years of teaching experience n_u_m years of professional/management experience n_u_m
# 4		years of teaching experience n_u_m years of professional
# 5		management experience n_u_m
# 4		years of teaching experience n_u_m years of professional/management experience n_u_m
# 4		years of teaching experience n_u_m years of professional
# 5		management experience n_u_m
# 4		years of teaching experience n_u_myears of professional
# 4		years of teaching experience n_u_myears of professional/management experience n_u_m
# 5		management experience n_u_m
# 4		years of teaching experience n_u_m years of professional/management experience n_u_m
# 4		years of teaching experience n_u_m years of professional
# 5		n_u_m year industry experience
# 4		n_u_m years of teaching experience/n_u_m year industry experience
# 7		n_u_m years of teaching experience
# 5		management experience n_u_m
# 4		years of teaching experience n_u_m years of professional/management experience n_u_m
# 4		years of teaching experience n_u_m years of professional
# 7		n_u_m years of teaching experience
# 5		n_u_m uyears of Industry Experience
# 4		n_u_m uyears of Industry Experience/n_u_m years of teaching experience
# 7		years of teaching experience
# 5		uyears of Industry Experience/n_u_m
# 6		CELTA and marketing Certification
# 3		n_u_m years teaching n_u_m years global industry Six Sigma CELTA
# 7		n_u_m years global industry Six Sigma CELTA and marketing Certification
# 7		n_u_m years global industry
# 7		n_u_m years teaching
# 3		n_u_m years teaching n_u_m years global industry Six Sigma CELTA and marketing Certification
# 6		Certification
# 6		marketing Certification
# 3		n_u_m years teaching n_u_m years working in business
# 2		n_u_m years working in business
# 7		n_u_m years teaching
# 6		Certified Notary Public and Certified Conveyancer
# 6		Certified Conveyancer
# 6		Certification
# 4		years of teaching experience n_u_m years of professional
# 2		n_u_m working in business
# 7		n_u_m years teaching
# 6		working in business
# 7		years teaching n_u_m
# 7		n_u_m years teaching n_u_m working in business
# 5		years of professional/management experience
# 4		years of teaching experience n_u_m years of professional
# 6		management experience
# 4		years of teaching experience n_u_m years of professional/management experience
# 7		years of teaching experience n_u_m
# 1		management experience n_u_m Six Sigma Green Belt
# 1		Six Sigma Green Belt
# 4		years of teaching experience n_u_m years of professional/management experience n_u_m
# 4		years of teaching experience n_u_m years of professional
# 7		n_u_m years teaching experience/n_u_m
# 7		n_u_m years industry
# 3		experience/n_u_m years industry/n_u_m years commercial training
# 7		years industry/n_u_m years commercial training
# 7		n_u_m years teaching
# 7		n_u_m years teaching experience
# 3		n_u_m years teaching experience/n_u_m years industry/n_u_m years commercial training
# 7		n_u_m years commercial training
# 5		years of professional/management experience n_u_m Professional Certification ICDL
# 7		years of teaching experience n_u_m
# 5		management experience n_u_m Professional Certification ICDL
# 4		years of teaching experience n_u_m years of professional
# 2		n_u_m years in Education
# 2		n_u_m years in industry
# 2		n_u_m years in industry n_u_m years in Education
# 2		years in industry n_u_m years in Education
# 5		management experience n_u_m Professional Certification Professional Trainer (CAP)
# 4		years of teaching experience n_u_m years of professional
# 5		management experience n_u_m Professional Certification ISW
# 6		TTW
# 4		years of teaching experience n_u_m years of professional
# 4		years of teaching experience n_u_m years of professional
# 5		management experience n_u_m Professional Certification ISW FTW and TTW
# 6		FTW and TTW
# 6		Certification
# 6		TTW
# 5		management experience n_u_m
# 4		years of teaching experience n_u_m years of professional/management experience n_u_m
# 4		years of teaching experience n_u_m years of professional
# 5		management experience n_u_m
# 4		years of teaching experience n_u_m years of professional/management experience n_u_m
# 4		years of teaching experience n_u_m years of professional
# 4		Six Sigma years of teaching experience n_u_m years of professional
# 5		management experience n_u_m
# 4		years of teaching experience n_u_m years of professional/management experience n_u_m
# 4		Six Sigma years of teaching experience n_u_m years of professional/management experience n_u_m
# 5		management experience n_u_m
# 4		years of teaching experience n_u_myears of professional
# 4		years of teaching experience n_u_myears of professional/management experience n_u_m
# 3		n_u_m years professional experience n_u_m teaching experience
# 6		Certificate Takaful Professional Certificate Isalmic Finance Executive
# 6		Certificate Isalmic Finance Executive
# 6		Certificate Takaful Professional
# 5		n_u_m years professional experience
# 6		Curriculum development experience
# 6		Certificate
# 3		n_u_m years professional experience n_u_m teaching experience and active researcher
# 5		n_u_m professional experience n_u_m teaching Trainer for CMA Exams and Accreditation experience
# 6		Accreditation experience
# 6		Trainer for CMA Exams and Accreditation experience
# 5		n_u_m professional experience n_u_m teaching Trainer for CMA Exams
# 5		n_u_m professional experience n_u_m teaching
# 7		n_u_m teaching Trainer for CMA Exams and Accreditation experience
# 5		n_u_m professional experience
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years professional experience n_u_m years teaching and active researcher
# 5		n_u_m years professional experience
# 6		and active researcher
# 6		active researcher
# 6		Aviation Finance
# 6		Accounting
# 6		Certified Supply Chain Analyst
# 6		many certifications in Aviation Law
# 7		n_u_m years teaching
# 6		certification
# 3		n_u_m years professional experience( mainly consulting) n_u_m years teaching mainly MBA
# 6		Certification
# 5		n_u_m years professional experience( mainly consulting)
# 6		Oil and Gas Accounting Certificate
# 6		Gas Accounting Certificate
# 6		EQUIS) grant writing
# 7		n_u_m years Reserach and teaching experience AACSB accreditaion and curriculum assessment
# 6		Certifications HRD Certificate Oil and Gas Accounting Certificate
# 6		curriculum assessment curricula design accreditation experience (AACSB
# 6		curricula design
# 6		reporting Certifications HRD Certificate Oil
# 6		and reporting Certifications HRD Certificate
# 6		teaching experience AACSB accreditaion
# 6		accreditation experience (AACSB and EQUIS)
# 6		Certificate
# 6		grant writing
# 7		n_u_m years Reserach and teaching experience
# 7		n_u_m years Reserach
# 5		management experience Professional Certification ICDL
# 4		years of teaching experience n_u_m years of professional
# 4		years of teaching experience n_u_m Industry experience n_u_m years
# 6		Certified ISO n_u_m Lead Assessor
# 6		Associate ICMA (Australia)
# 6		Certification
# 7		Teaching n_u_m years
# 3		Work experience n_u_m years Teaching n_u_m years
# 7		Teaching n_u_m years Certifications Associate of ICSA (Singapore UK)
# 0		Work experience n_u_m years
# 4		Years of teaching Exp n_u_m Years of Industry Exp n_u_m
# 5		/ Mgmt Experience n_u_m Prof
# 6		TQM Management Certification Professional Online Instructor Certification
# 7		Years of Teaching Experience n_u_m
# 6		TQM Management Certification
# 6		Professional Online Instructor Certification
# 4		Years of Teaching Experience n_u_m Years of Prof
# 5		Years of Prof/ Mgmt Experience n_u_m
# 6		Certification
# 4		Years of Teaching Experience – n_u_m years Industry Experience – n_u_m years
# 5		Management/Supervisory Experience – n_u_m years Prof Certifications – CELTA Associate of ACFE (US)
# 6		Certifications – CELTA Associate of ACFE (US)
# 0		More than n_u_m years work experience
# 5		n_u_m years industry experience
# 3		n_u_m years industry experience n_u_m years teaching experience
# 7		n_u_m years teaching
# 6		from Cambridge University
# 6		Certificate
# 4		Years of Teaching Experience n_u_m Years of Professional
# 5		Management Expirience n_u_m Professional Certifications Oracle Certification
# 4		Years of Teaching Experience n_u_m Years of Professional
# 5		Management Experience n_u_m years Professional Certifications Oracle Certification
# 4		Years of Teaching Experience n_u_m years Years of Professional
# 5		n_u_m years Professional
# 3		n_u_m years Professional n_u_m years Teaching
# 7		n_u_m years Teaching
# 5		Management Expirience n_u_m yrs Professional Certifications PGCTHE & CELTA
# 4		Years of Teaching Experience n_u_m yrs Years of Professional
# 4		Years of management experience n_u_m years
# 2		years Graduate Certificate in tertiary teaching
# 2		Graduate Certificate in tertiary teaching
# 4		Years of teaching experience n_u_m years Years of management experience n_u_m
# 4		Years of teaching experience n_u_m years
# 4		Years of Teaching Experience n_u_m yrs Years of Professional/Management Expirience n_u_m yrs
# 4		Years of Teaching Experience n_u_m yrs Years of Professional
# 6		Management Expirience n_u_m yrs
# 7		years teaching experience n_u_m
# 3		years teaching experience n_u_m management experiece n_u_m years
# 7		n_u_m years teaching
# 7		n_u_m years teaching experience
# 5		experience n_u_m years profesional management experience
# 3		n_u_m years teaching experience n_u_m years profesional management experience
# 5		n_u_m years profesional management experience
# 6		Program manager coordinator and
# 6		tender writer Program manager coordinator
# 7		Program manager for HND BTEC Syallabus from n_u_m to n_u_m
# 6		module writer
# 6		Program developer module writer leader and tender writer
# 6		Program manager coordinator and certified developer for the Retailing program Bahrain
# 6		leader and tender writer Program manager
# 6		More than n_u_m
# 2		n_u_m in association wi EFI International Australia
# 6		Internal verifier for HND BTEC edexcel UK
# 7		n_u_m Years Teaching
# 7		Descriptor and outcomes based learning practitioner from n_u_m to n_u_m
# 7		n_u_m Years Teaching Experience
# 5		Approximate n_u_m Yrs Industrial Experience including positions held at management level
# 7		n_u_m years Student Services Administration
# 2		n_u_mYear in National Bank of Fujairah & n_u_m years in Student and Academic Services Department
# 6		Academic Services Department
# 6		n_u_mYear in National Bank of Fujairah
# 2		n_u_mYear in National Bank of Fujairah & n_u_m years in Student
# 2		n_u_m years in Student and Academic Services Department
# 5		n_u_m/n_u_m Years in Industrial Experience
# 3		n_u_m & n_u_m/n_u_m Years in Industrial Experience
# 2		n_u_m Years in Industrial Experience
# 2		n_u_m year experience in Student and Academic Services
# 2		n_u_m year experience in Student and Academic Services CELTA
# 6		Academic Services CELTA
# 2		n_u_m year experience in Student
# 2		Experience Certificate in Teaching Profession Mini CELTA
# 2		n_u_m Years Teaching Experience Certificate in Teaching Profession
# 2		n_u_m Years Teaching Experience Certificate in Teaching Profession Mini CELTA
# 6		Mini CELTA
# 2		Certificate in Teaching Profession Mini CELTA
# 7		n_u_m Years Teaching
# 6		Certificate
# 7		n_u_m Years Teaching Experience
# 2		Years Teaching Experience Certificate in Teaching Profession Mini CELTA
# 2		Certificate in Teaching Profession
# 6		personal development
# 2		n_u_m years as recruitment officer in Al Sharq Hospital
# 6		strategic planning and personal development
# 4		n_u_m years of industry experience and n_u_m Years Teaching Experience
# 5		n_u_m years of industry experience and
# 7		n_u_m Years Teaching Experience CELTA
# 6		Experience CELTA
# 7		n_u_m Years Teaching
# 4		n_u_m years of industry experience and n_u_m Years Teaching Experience CELTA
# 5		n_u_m years of industry experience
# 2		Harvard Certificate in Teaching for Understanding
# 7		n_u_m years Teaching Experience
# 5		n_u_m years of professional management experience
# 2		n_u_m years of professional management experience Harvard Certificate in Teaching for Understanding
# 6		Certificate
# 7		n_u_m years Teaching
# 6		Instructional Skills Workshop Certificate n_u_m
# 4		n_u_m Years Teaching Experience n_u_m Years of professional/management experience
# 5		management experience Instructional Skills Workshop Certificate n_u_m
# 5		n_u_m Years of professional/management experience Instructional Skills Workshop Certificate n_u_m
# 7		n_u_m Years Teaching
# 6		Certificate
# 3		n_u_m Years Teaching Experience n_u_m Years of professional
# 7		n_u_m Years Teaching Experience
# 5		n_u_m Years of professional/management experience Instructional Skills Workshop Certificate
# 2		n_u_m years experience in administration
# 4		n_u_m Years of Teaching Experience n_u_m years of Management and Business experience in HR
# 2		Business experience in HR & IT training
# 6		Project Management for Executives
# 6		Academic professionals
# 7		n_u_m Years of Teaching Experience
# 4		n_u_m Years of Teaching Experience n_u_m years of Management
# 6		IT training and Project Management for Executives and Academic professionals
# 3		n_u_m years professional experience n_u_m years teaching
# 3		n_u_m years professional experience n_u_m years teaching Certifications_ CPA Virginia and CGMA
# 6		Certifications_ CPA Virginia and CGMA
# 5		n_u_m years professional experience
# 3		n_u_m years professional experience n_u_m years teaching Certifications_ CPA Virginia
# 7		n_u_m years teaching Certifications_ CPA Virginia and CGMA
# 6		active researcher Curriculum development
# 3		n_u_m years professional experience n_u_m years tecahing
# 5		n_u_m years professional experience
# 3		n_u_m years professional experience n_u_m years tecahing and active researcher
# 6		Curriculum development and accreditation background
# 6		accreditation background
# 7		n_u_m years tecahing and active researcher Curriculum development and accreditation background
# 5		n_u_m years of industrrial experience
# 5		n_u_m years of higher education teacing experience
# 4		n_u_m years of higher education teacing experience and n_u_m years of industrrial experience
# 5		Logistics Industry Experience n_u_m Years Teaching Experience
# 5		n_u_m Years Transport and Logistics Industry Experience
# 7		n_u_m Years Transport
# 3		n_u_m Years Transport and Logistics Industry Experience n_u_m Years Teaching Experience
# 7		n_u_m Years Teaching
# 7		n_u_m years of higher education Teaching Experience
# 6		ISOn_u_m Quality Management)
# 2		Lead Auditor in (ISO/IECn_u_m n_u_m IT Service Management
# 6		ISOn_u_m Business Continuity Management
# 5		n_u_m year of Industry experience
# 6		IECn_u_m n_u_m IT Service Management ISO
# 6		ISO/IECn_u_m Information Security Management
# 7		n_u_m years of
# 0		n_u_m years work experience
# 5		years professional work experience
# 5		n_u_m years professional work experience
# 0		years work experience n_u_m
# 0		n_u_m years work experience n_u_m years professional work experience
# 6		and has good research training
# 3		n_u_m years profesional experience n_u_m years teaching and has good research training
# 7		n_u_m years teaching and has good research training
# 6		has good research training
# 7		n_u_m years teaching
# 5		n_u_m years profesional experience
# 3		n_u_m years profesional experience n_u_m years teaching
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 6		n_u_m Industry
# 7		years teaching
# 7		n_u_m years teaching
# 6		Industry and n_u_m
# 7		n_u_m Industry and n_u_m years teaching
# 0		years teaching experience n_u_m years work experience in HR
# 3		n_u_m years teaching experience n_u_m years work experience in HR
# 0		n_u_m years work experience in HR
# 7		n_u_m years teaching experience
# 0		n_u_m year work experience
# 3		n_u_m years teaching experience n_u_m years work experience product management
# 0		n_u_m years work experience product management and marketing
# 7		n_u_m years teaching experience
# 3		n_u_m years teaching experience n_u_m years work experience product management and marketing
# 0		years teaching experience n_u_m years work experience product management and marketing
# 2		years work experience in sales
# 7		n_u_m years teaching
# 3		n_u_m years teaching n_u_m years work experience in sales
# 0		n_u_m years work experience in sales
# 7		years teaching n_u_m
# 6		Professional Certified Trainer
# 6		years Business and Marketing Management Professional Certified Trainer
# 7		n_u_m years Business and Marketing Management
# 7		n_u_m Years Teaching experience
# 6		Marketing Management Professional Certified Trainer
# 3		n_u_m Years Teaching experience n_u_m years Business
# 7		Years Teaching experience n_u_m
# 7		Years Teaching n_u_m Years industry experience (Banking)
# 3		n_u_m Years Teaching n_u_m Years industry experience (Banking)
# 7		n_u_m Years Teaching
# 5		n_u_m Years industry experience (Banking)
# 2		started teaching in Sept n_u_m work experience in IT support services for n_u_m years
# 2		started teaching in Sept n_u_m work experience in IT support services for n_u_m
# 2		started teaching in Sept n_u_m
# 0		work experience in IT support services for n_u_m years
# 6		business development
# 2		years work experience in real estate and business development
# 3		n_u_m years teaching experience n_u_m years work experience in real estate and business development
# 3		n_u_m years teaching experience n_u_m years work experience in real estate
# 0		n_u_m years work experience in real estate and business development
# 7		years teaching experience n_u_m
# 7		n_u_m years teaching experience
# 2		n_u_m years industry (Finance) Professional Certificate in Business Accounting
# 3		n_u_m Years teaching n_u_m years industry (Finance) Professional Certificate in Business Accounting
# 7		n_u_m Years teaching
# 6		Certificate
# 3		n_u_m years Professional n_u_m years teaching Member of Research and Exam Committee
# 7		n_u_m years teaching Member of Research and Exam Committee
# 6		Member of Research and Exam Committee
# 3		n_u_m years Professional n_u_m years teaching Member of Research
# 6		Exam Committee
# 5		n_u_m years Professional
# 3		n_u_m years Professional n_u_m years teaching
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 6		Also Curriculum development experience
# 3		n_u_m years professional experience n_u_m years teaching
# 5		n_u_m years professional experience
# 6		Certification
# 6		Advance Online Systems Also Curriculum development experience
# 6		Global Professional IN Human Resources(GPHR)
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching
# 5		n_u_m years professional experience
# 5		n_u_m years professional experience
# 3		n_u_m years professional experience n_u_m years teaching(Online course design
# 6		active researcher
# 6		delivery)
# 7		n_u_m years teaching(Online course design and delivery) and active researcher
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years professional (consulting) experience n_u_m years teaching and active researcher
# 6		and active researcher
# 3		n_u_m years professional (consulting) experience n_u_m years teaching
# 6		active researcher
# 5		n_u_m years professional (consulting) experience
# 2		industry experience in New Zeal
# 6		Member of the Institute of Chartered Accountants in New Zealand
# 7		n_u_m Years experience teaching at tertiary level
# 7		n_u_m years government
# 6		AustraliaMember of the Institute of Chartered Accountants in New Zeal
# 2		n_u_m years government and industry experience in New Zealand and Australia
# 6		Bo at Undergraduate and Postgraduate levels
# 4		n_u_m years of Industry Experience and n_u_m years of Teaching Experience
# 5		n_u_m years of Industry Experience
# 6		Postgraduate levels
# 7		n_u_m years of Teaching Experience Bo at Undergraduate
# 7		n_u_m years higher education teaching experience
# 3		n_u_m years as branch manager n_u_m years higher education teaching experience
# 5		n_u_m years industrial experience
# 2		n_u_m years in production line
# 3		n_u_m years industrial experiencen_u_m years in production line n_u_m years as branch manager
# 0		More than n_u_m years work experience
# 0		More than n_u_m years work experience
# 6		NTIS) n_u_m PMP Project Management Certification
# 6		Assessments (TAAn_u_m) Australian Business Academy (ABRA
# 6		PMP Project Management Certification
# 7		n_u_m years teaching
# 7		n_u_m years teaching experience
# 0		More than n_u_m years work experience
# 6		Certified in team based learning (USA)
# 6		Certified in Neuro Linguistic Programming (Canada)
# 2		Certificate in Teaching Methodology in Higher Education
# 6		Specialist in European Law
# 6		Hungarian Bar Exam
# 6		Hungarian Bar Exam Specialist in European Law
# 0		More than n_u_m years work experience
# 6		CPA (California
# 0		More than n_u_m years work experience CPA (California USA)
# 6		Accounting Technician(UK)
# 3		n_u_m years professional experience n_u_m teaching experience
# 6		Certifications Registered Cost Accountant(UK) and Accounting Technician(UK)
# 5		n_u_m years professional experience
# 3		n_u_m years professional experience n_u_m years teaching (Online course design and delivery)
# 7		n_u_m years teaching
# 3		n_u_m years professional experience n_u_m years teaching (Online course design
# 5		n_u_m years professional experience
# 6		Certifications Certified Manangement Account CMA Institute of Management Accountants IMA
# 6		Certification
# 6		Training and Executive Education background
# 6		delivery) Training
# 6		Institute of Management Accountants IMA
# 5		n_u_m years tecahing experience and active reseracher Experience in Innovation Unit
# 2		Experience in Innovation Unit
# 6		active reseracher Experience in Innovation Unit
# 3		n_u_m years professional experience n_u_m years tecahing experience and active reseracher
# 5		n_u_m years professional experience
# 3		n_u_m years professional experience n_u_m years tecahing experience
# 6		Licensed Agriculturist
# 6		Certified Financial Planner (CFP)
# 0		More than n_u_m years work experience
# 6		Chartered Financial Analyst (CFA)
# 6		Certified Management Accountant (CMA)
# 0		More than n_u_m years work experience
# 0		More than n_u_m years work experience
# 0		More than n_u_m years work experience
# 6		certified as an applied instructor in innovations
# 0		More than n_u_m years work experience
# 0		More than n_u_m years work experience certified as an applied instructor in innovations
# 6		Certificate III for Professional Workplace Coaches
# 0		More than n_u_m years work experience
# 0		More than n_u_m years work experience
# 0		More than n_u_m years work experience
# 6		BUS n_u_m_(Financial Management) n_u_m Course Credits
# 0		More than n_u_m years work experience
# 0		More than n_u_m Years work experience qualified security trader (Canadian Securities Institute)
# 0		More than n_u_m Years work experience
# 6		qualified security trader (Canadian Securities Institute)
# 0		More than n_u_m years work experience
# 0		More than n_u_m years work experience
# 0		More than n_u_m years work experience
# 0		More than n_u_m years work experience Certified Train the Trainer
# 6		Certified Train the Trainer
# 0		More than n_u_m years work experience
# 6		HCIMA CTHCM
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years professional experience n_u_m years teaching and active researcher
# 6		Curriculum Development experience
# 5		n_u_m years professional experience
# 6		and active researcher
# 7		n_u_m years teaching and active researcher Curriculum Development experience
# 6		active researcher Curriculum Development experience
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years professional experience n_u_m years teaching and active researcher
# 5		n_u_m years professional experience
# 6		and active researcher
# 6		active researcher
# 3		n_u_m years professional( consulting) experience n_u_m years teaching and active researcher
# 5		n_u_m years professional( consulting) experience
# 6		active researcher Curriculum development
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years professional( consulting) experience n_u_m years teaching
# 6		Curriculum development and research publishing experience
# 6		and active researcher
# 6		and research publishing experience
# 6		research publishing experience
# 6		Certifications CIPD Case Study Methods Research Methods
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching and active researcher Certifications CIPD Case Study Methods Research Methods
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years professional experience n_u_m years teaching and active researcher
# 5		n_u_m years professional experience
# 6		and active researcher
# 3		n_u_m years professional experience n_u_m years teaching and active researcher Certifications CIPD
# 6		Certification
# 6		Case Study Methods
# 6		Research Methods
# 6		active researcher Certifications CIPD Case Study Methods Research Methods
# 3		n_u_m years professional experience n_u_m years teaching
# 7		n_u_m years teaching and active researcher
# 3		n_u_m years professional experience n_u_m years teaching and active researcher
# 5		n_u_m years professional experience
# 6		and active researcher
# 6		active researcher
# 6		Accreditation background
# 7		n_u_m year teaching and active researcher
# 6		active researcher Accreditation background
# 3		n_u_m years professional experience n_u_m year teaching
# 5		n_u_m years professional experience
# 6		and active researcher
# 3		n_u_m years professional experience n_u_m year teaching and active researcher
# 7		n_u_m year teaching and active researcher Accreditation background
# 3		n_u_m years professional experience n_u_m year teaching and active researcher Accreditation background

# %% [markdown]
# From the above output, it looks like "n_u_m Years Teaching" and similar phrases were rightly put into the same cluster.
#
# We can do more optimisations around regexes, sanitisation, to have cleaner clusters. This is an iterative process.
